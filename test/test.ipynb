# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
image = Image.open("Unequalized_Hawkes_Bay_NZ.jpg")

# %%
bwimg = np.sum(image, axis=2)
bwimg = np.array(np.floor(bwimg/3), dtype=np.int16)
plt.imshow(bwimg, cmap="gray", vmin=0, vmax=255)
plt.show()

# %%
histo_data = np.histogram(bwimg, bins=256)[0]
plt.bar(np.arange(len(histo_data)), histo_data)
plt.show()

# %%
max_index = np.argmax(histo_data)
last_zero = -1
for i in range(max_index-1, -1, -1):
    if histo_data[i] == 0:
# Out:
# 0
# 0
# 25696
# 0
# 22186
# 0
# 0
# 19125
# 0
# 0
# 16115
# 0
# 13530
# 0
# 0
# 10610
# 0
# 0
# 8463
# 0
# 0
# 6395
# 0
# 5108
# 0
# 0
# 4039
# 0
# 0
# 3259
# 0
# 0
# 2718
# 0
# 2160
# 0
# 0
# 1747
# 0
# 0
# 1061
# 0
# 488
# 0
# 0
# 220
# 0
# 0
# 93
# 0
# 0
# 49
# 0
# 19
# 0
# 0
# 12
# 0
# 0
# 1
# 0
# 1
